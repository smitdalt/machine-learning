# %% [markdown]
# #### Pain + Opiod + LBP ICD9 Plots
#
# Jay Urbain

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets
# %matplotlib inline 

data = {'Female':[43,1157,2705,3103,4793,4903,6385],
          'Male':[35, 462,1130,1787,3183,3303,3592]}
df = pd.DataFrame(data, index=['0-19', '20-29', '30-39', '40-49', '50-59', '60-69', '70plus'])

# %%
df.plot(kind='bar', stacked=False, alpha=0.5, title='Opioid + LBP ICD9 + Pain>=4')

# %%
df.plot(kind='barh', stacked=False, alpha=0.5, title='Opioid + LBP ICD9 + Pain>=4')

# %%
df.plot(kind='bar', stacked=True, alpha=0.5, title='Opioid + LBP ICD9 + Pain>=4')

# %%
df.plot(kind='barh', stacked=True, alpha=0.5, title='Opioid + LBP ICD9 + Pain>=4')
